# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

folder= '/content/drive/MyDrive/Colab Notebooks/MonAn/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'BanhXeo('+str(i+1) + ').jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %% [markdown]
# **TẠO DỰ LIỆU**

# %%
folder = '/content/drive/MyDrive/Colab Notebooks/MonAn/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('BanhBao'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhChung'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhHoi'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhMi'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhXeo'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('ChaRam'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Comtam'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Cua'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('pho'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('TrungLon'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)
# Out:
# (80, 200, 200, 3) (80,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', 
                 input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

#Biên dịch
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Training
history = model.fit(photos, labels, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 8s 2s/step - loss: 3984.0327 - accuracy: 0.1375
# Epoch 2/50
# 3/3 [==============================] - 5s 2s/step - loss: 3884.2590 - accuracy: 0.1000
# Epoch 3/50
# 3/3 [==============================] - 5s 2s/step - loss: 379.4209 - accuracy: 0.2125
# Epoch 4/50
# 3/3 [==============================] - 5s 2s/step - loss: 80.0494 - accuracy: 0.3250
# Epoch 5/50
# 3/3 [==============================] - 5s 2s/step - loss: 9.4264 - accuracy: 0.7000
# Epoch 6/50
# 3/3 [==============================] - 5s 2s/step - loss: 5.4843 - accuracy: 0.8250
# Epoch 7/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.1490 - accuracy: 0.9125
# Epoch 8/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.3309 - accuracy: 0.9625
# Epoch 9/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0974 - accuracy: 0.9375
# Epoch 10/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0867 - accuracy: 0.9625
# Epoch 11/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.0960 - accuracy: 0.9500
# Epoch 12/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0458 - accuracy: 0.9875
# Epoch 13/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 14/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 15/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 16/50
# 3/3 [==============================] - 6s 2s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 17/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 18/50
# 3/3 [==============================] - 5s 2s/step - loss: 6.1773e-04 - accuracy: 1.0000
# Epoch 19/50
# 3/3 [==============================] - 5s 2s/step - loss: 3.3515e-04 - accuracy: 1.0000
# Epoch 20/50
# 3/3 [==============================] - 5s 2s/step - loss: 2.1753e-04 - accuracy: 1.0000
# Epoch 21/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.5886e-04 - accuracy: 1.0000
# Epoch 22/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.0461e-04 - accuracy: 1.0000
# Epoch 23/50
# 3/3 [==============================] - 5s 2s/step - loss: 7.6593e-05 - accuracy: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 5s 2s/step - loss: 5.9960e-05 - accuracy: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 5s 2s/step - loss: 3.3975e-05 - accuracy: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 5s 2s/step - loss: 2.6180e-05 - accuracy: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.7990e-05 - accuracy: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.2485e-05 - accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 5s 2s/step - loss: 8.7562e-06 - accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 5s 2s/step - loss: 5.6941e-06 - accuracy: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 5s 2s/step - loss: 4.5099e-06 - accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 5s 2s/step - loss: 2.9814e-06 - accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 5s 2s/step - loss: 2.6686e-06 - accuracy: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.9862e-06 - accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.5482e-06 - accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.1354e-06 - accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.0624e-06 - accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 5s 2s/step - loss: 8.6127e-07 - accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 5s 2s/step - loss: 7.7187e-07 - accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 5s 2s/step - loss: 6.8395e-07 - accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 5s 2s/step - loss: 6.3925e-07 - accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 5s 2s/step - loss: 5.8859e-07 - accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 6s 2s/step - loss: 5.4687e-07 - accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 5s 2s/step - loss: 5.1409e-07 - accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 5s 2s/step - loss: 4.7981e-07 - accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 5s 2s/step - loss: 4.5895e-07 - accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 5s 2s/step - loss: 4.3511e-07 - accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 6s 2s/step - loss: 4.1276e-07 - accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 5s 2s/step - loss: 3.9190e-07 - accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 5s 2s/step - loss: 3.7402e-07 - accuracy: 1.0000

# %%
model.save('10Foods_Final.h5')

# %%
classes = ["Banhbao","BanhChung","BanhHoi","BanhMi","BanhXeo","ChaRam","ComTam","Cua","pho","TrungLon"]

# %%
from keras.preprocessing.image import load_img, img_to_array, array_to_img
import numpy as np
img = load_img('banhmi.jpg', target_size=(200,200))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,200,200,3)
img = img.astype('float32')
img/=255
y_pred = model.predict(img)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09741412 0.10475393 0.11216005 0.1190367  0.08347126 0.11143894
#   0.09749522 0.07087862 0.09752628 0.10582487]]
# 'BanhMi'

# %%
from keras.preprocessing.image import load_img, img_to_array, array_to_img
import numpy as np
img = load_img('banhchung.jpg', target_size=(200,200))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,200,200,3)
img = img.astype('float32')
img/=255
y_pred = model.predict(img)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.08972789 0.11040351 0.1039189  0.10152606 0.1090937  0.09603863
#   0.09594177 0.08026334 0.10506143 0.10802477]]
# 'BanhChung'

# %%
from keras.preprocessing.image import load_img, img_to_array, array_to_img
import numpy as np
img = load_img('trunglon.jpg', target_size=(200,200))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,200,200,3)
img = img.astype('float32')
img/=255
y_pred = model.predict(img)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.10587307 0.11005053 0.10009355 0.11012165 0.08258292 0.10272589
#   0.08932478 0.0785202  0.10523503 0.11547232]]
# 'TrungLon'

# %%
from keras.preprocessing.image import load_img, img_to_array, array_to_img
import numpy as np
img = load_img('pho.jpg', target_size=(200,200))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,200,200,3)
img = img.astype('float32')
img/=255
y_pred = model.predict(img)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.10218861 0.10534047 0.10341353 0.0999889  0.09955739 0.0995168
#   0.09311148 0.08692691 0.10537538 0.10458051]]
# 'pho'

# %%
from keras.preprocessing.image import load_img, img_to_array, array_to_img
import numpy as np
img = load_img('ram.jpg', target_size=(200,200))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,200,200,3)
img = img.astype('float32')
img/=255
y_pred = model.predict(img)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.10700434 0.09642666 0.10022982 0.10395596 0.09771604 0.10570865
#   0.09788206 0.09062548 0.10025772 0.10019333]]
# 'Banhbao'
